# %% [markdown]
# 1) Начнём с простого - сохраните в переменную age произвольный возраст, выраженный целым числом, а в переменную name какое-нибудь имя в виде строки

# %%
age = 38
name = 'Kostya'

# %% [markdown]
# 2) Создайте список user_info, содержащий 2 строки (имя и фамилия пользователя), 1 дробное число (зарплата) и 1 целое число (стаж)

# %%
user_info = ['Kostya', 'Medvedev', 83009.56, 7]

# %%
salaries = [80000, 100000, 120000,]
first = salaries[0]

# %%
first
# Out:
# 80000

# %% [markdown]
# Добавьте в список users элементы 'Voronov' и 42

# %%
user = ['John', 67, 'Lee', 43]
user
user.append('Voronov')
user.append(42)
user
# Out:
# ['John', 67, 'Lee', 43, 'Voronov', 42]

# %% [markdown]
# В переменной user_ages содержится список возрастов клиентов. Напишите петлю, выводящую на печать возраста, которые больше 18
# Пример данных, которые могут быть в user_ages
# user_ages = [10, 18, 21, 35, 42, 27, 12, 16]

# %%
user_ages = [10, 18, 21, 35, 42, 27, 12, 16]

# %%
for i in user_ages:
    print(i)
# Out:
# 10
# 18
# 21
# 35
# 42
# 27
# 12
# 16

# %%
for i in user_ages:
    if i > 18:
        print(i)
# Out:
# 21
# 35
# 42
# 27

# %%
salaries = [1,2,3,4,5,6,7,8]
salaries[0]
salaries[-1]
# Out:
# 8

# %%
salaries[0]
# Out:
# 1

# %%
#salaries[12]

# %%
for i in user_ages:
    print(i+10)
    print(i/100)
print('end')
# Out:
# 20
# 0.1
# 28
# 0.18
# 31
# 0.21
# 45
# 0.35
# 52
# 0.42
# 37
# 0.27
# 22
# 0.12
# 26
# 0.16
# end

# %%
if 10 > 5:
    print(True)
# Out:
# True

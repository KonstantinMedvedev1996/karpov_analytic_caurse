# %%
def first_function():
    print("Hello world!")
first_function()
first_function()
# Out:
# Hello world!
# Hello world!

# %%
first_function()
# Out:
# Hello world!

# %% [markdown]
# def get_time_tuple(distance, speed):
#     # Получаем целое число часов в пути
#     hours = distance // speed
#     # Получаем остаток км в пути
#     distance_left = distance % speed
#     # Переводим скорость из км/ч в км/мин:
#     # за одну минуту можно проехать расстояние
#     # в 60 раз меньше, чем за 1 час
#     kms_per_minute = speed / 60
#     # Делим оставшееся расстояние на скорость в км/мин.
#     # и округляем до целого
#     minutes = round(distance_left / kms_per_minute)
#
#     # Перечисляем аргументы через запятую.
#     # Они будут возвращены функцией в виде кортежа.
#     return hours, minutes

# %%
def print_hours(minutes):
    # // — это оператор целочисленного деления
    hours = minutes // 60
    # % — это оператор получения остатка от деления
    left_minutes = minutes % 60
    print("Hours:", hours)
    print("Minutes left:", left_minutes)
    
print_hours(90)
# Будет напечатано:
# Out:
# Hours: 1
# Minutes left: 30

# %%
print_hours(134)
# Out:
# Hours: 2
# Minutes left: 14

# %%
def get_time(distance, speed):
    # В переменную result сохраним результат
    # деления расстояния на скорость.
    result = distance / speed

    # Чтобы вернуть результат вычислений,
    # пишем оператор return и название переменной,
    # значение которой будет передано.
    return result

# %%
time = round(get_time(120, 7),2)
print("Travel time will be:", time, "hours")
# Out:
# Travel time will be: 17.14 hours

# %%
def get_time_tuple(distance, speed):
    # Получаем целое число часов в пути
    hours = distance // speed
    # Получаем остаток км в пути
    distance_left = distance % speed
    # Переводим скорость из км/ч в км/мин:
    # за одну минуту можно проехать расстояние
    # в 60 раз меньше, чем за 1 час
    kms_per_minute = speed / 60
    # Делим оставшееся расстояние на скорость в км/мин.
    # и округляем до целого
    minutes = round(distance_left / kms_per_minute)
    
    # Перечисляем аргументы через запятую.
    # Они будут возвращены функцией в виде кортежа.
    return hours, minutes

# %%
result = get_time_tuple(120, 100)
print(result)
# Out:
# (1, 12)

# %%
print("Hours to travel:", result[0])
print("Minutes to travel:", result[1])
# Out:
# Hours to travel: 1
# Minutes to travel: 12

# %%
hours, minutes = get_time_tuple(120, 100)
# Красиво напечатаем результат
print("Hours to travel:", hours)
print("Minutes to travel:", minutes)
# Out:
# Hours to travel: 1
# Minutes to travel: 12

# %%
def in_list(list_in, obj):
    for elem in list_in:
        if obj == elem:
            print("Element is found!")
            return True
            print("This won’t be printed")
    print("Element is NOT found!")
    return False
    print("This will not be printed either")

# %%
my_list = [1,2,5,7,10]

# %%
result = in_list(my_list, 3)
# Out:
# Element is NOT found!

# %%
print(result)
# Out:
# False

# %%
result = in_list(my_list, 7)
print(result)
# Out:
# Element is found!
# True

# %%
def get_total(units, price):
    return units*price

# %%
print(get_total(15, 50))
# Out:
# 750

# %%
grades = {'Ivanov': 5, 'Smirnov': 3, 'Kuznetsova': 4, 'Tihonova': 5}
# Напечатаем оценку студента, которого нет в словаре
print(grades['Pavlov'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [24], in <cell line: 3>()
#       1 grades = {'Ivanov': 5, 'Smirnov': 3, 'Kuznetsova': 4, 'Tihonova': 5}
#       2 # Напечатаем оценку студента, которого нет в словаре
# ----> 3 print(grades['Pavlov'])
#
# KeyError: 'Pavlov'

# %%
try:
    print(grades['Pavlov'])
# А если возникнет ошибка в ключе (KeyError), скажем,
# что студента нет в словаре
except KeyError:
    print("Student’s mark was not found!")
# Out:
# Student’s mark was not found!

# %%
def get_time(distance, speed):
    # Если расстояние или скорость отрицательные, то возвращаем ошибку
    if distance < 0 or speed < 0:
        # Оператор raise возвращает (raise — досл. англ. "поднимать")
        # объект-исключение. В данном случае ValueError (некорректное значение).
        # Дополнительно в скобках после слова ValueError пишем текст сообщения
        # об ошибке, чтобы сразу было понятно, чем вызвана ошибка.
        raise ValueError("Distance or speed cannot be below 0!")
    if speed == 0:
        raise ValueError("speed cannot be equal 0!")
    result = distance / speed
    return result

# %%
get_time(500, 6)
# Out:
# 83.33333333333333

# %%
get_time(50, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 get_time(50, 0)
#
# Input In [31], in get_time(distance, speed)
#       8     raise ValueError("Distance or speed cannot be below 0!")
#       9 if speed == 0:
# ---> 10     raise ValueError("speed cannot be equal 0!")
#      11 result = distance / speed
#      12 return result
#
# ValueError: speed cannot be equal 0!

# %%
get_time(-50, 7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 get_time(-50, 7)
#
# Input In [31], in get_time(distance, speed)
#       1 def get_time(distance, speed):
#       2     # Если расстояние или скорость отрицательные, то возвращаем ошибку
#       3     if distance < 0 or speed < 0:
#       4         # Оператор raise возвращает (raise — досл. англ. "поднимать")
#       5         # объект-исключение. В данном случае ValueError (некорректное значение).
#       6         # Дополнительно в скобках после слова ValueError пишем текст сообщения
#       7         # об ошибке, чтобы сразу было понятно, чем вызвана ошибка.
# ----> 8         raise ValueError("Distance or speed cannot be below 0!")
#       9     if speed == 0:
#      10         raise ValueError("speed cannot be equal 0!")
#
# ValueError: Distance or speed cannot be below 0!

# %%
try:
    print(get_time(100, 0))
    
#должна завершиться с ошибкой ValueError, которую мы выведем в блоке except
except ValueError as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#       1 try:
# ----> 2     print(get_time(100, 0))
#       3 #должна завершиться с ошибкой ValueError, которую мы выведем в блоке except
#
# Input In [31], in get_time(distance, speed)
#       9 if speed == 0:
# ---> 10     raise ValueError("speed cannot be equal 0!")
#      11 result = distance / speed
#
# ValueError: speed cannot be equal 0!
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#       2     print(get_time(100, 0))
#       3 #должна завершиться с ошибкой ValueError, которую мы выведем в блоке except
# ----> 4 except ValueError("Speed cannot be equal to 0!") as e:
#       5     print(e)
#
# TypeError: catching classes that do not inherit from BaseException is not allowed

# %%
def get_cola(ice=True):
    if ice:
        print("Cola with ice is ready!")
    else:
        print("Cola without ice is ready!")

# %%
get_cola()
# Out:
# Cola with ice is ready!

# %%
get_cola(ice = False)
# Out:
# Cola without ice is ready!

# %%
get_cola(ice = True)
# Out:
# Cola with ice is ready!

# %%
def get_cola2(ice):
    if ice == True:
        print("Cola with ice is ready!")
    else:
        print("Cola without ice is ready!")

# %%
get_cola2(False)
# Out:
# Cola without ice is ready!

# %%
def root(value, n):
    # Как мы уже выяснили, чтобы посчитать
    # корень степени n из числа, можно возвести это число
    # в степень 1/n
    result = value ** (1/n)
    return result

# Посчитаем корень 3-ей степени (кубический корень) из 27
print(root(27, 3))
# Будет напечатано:
# 3.0
# Out:
# 3.0

# %%
def root(value, n = 2):
    # Как мы уже выяснили, чтобы посчитать
    # корень степени n из числа, можно возвести это число
    # в степень 1/n
    result = value ** (1/n)
    return result

# %%
root(9)
# Out:
# 3.0

# %%
root(16)
# Out:
# 4.0

# %%
root(8,3)
# Out:
# 2.0

# %%
def add_mark(name, mark, journal={}):
    # Присваиваем имени в журнале переданную оценку
    journal[name] = mark
    return journal

# %%
group1 = {}
# Добавим оценки двух студентов
group1 = add_mark('Ivanov', 5, group1)
group1 = add_mark('Tihonova', 4, group1)
print(group1)
# Out:
# {'Ivanov': 5, 'Tihonova': 4}

# %%
def add_mark(name, mark, journal=None):
    # Добавьте здесь проверку аргумента mark
    if journal is None:
        journal = {}
    journal[name] = mark
    return journal

# %%
def add_mark(name, mark, journal=None):
   # Добавьте здесь проверку аргумента mark
    if (mark > 5)or(mark < 2):
        raise ValueError('Invalid Mark!')
    if journal is None:
        journal = {}
    journal[name] = mark
    return journal

#попытка вызвать функцию с некорректными аргументами

# %%
try:
    print(add_mark('Ivanov', 6))
#должна завершиться с ошибкой ValueError, которую мы выведем в блоке except
except ValueError as e:
    print(e)
# Out:
# Invalid Mark!

# %%
print(add_mark('Ivanov', 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 print(add_mark('Ivanov', 1))
#
# Input In [67], in add_mark(name, mark, journal)
#       1 def add_mark(name, mark, journal=None):
#       2    # Добавьте здесь проверку аргумента mark
#       3     if (mark > 5)or(mark < 2):
# ----> 4         raise ValueError('Invalid Mark!')
#       5     if journal is None:
#       6         journal = {}
#
# ValueError: Invalid Mark!
